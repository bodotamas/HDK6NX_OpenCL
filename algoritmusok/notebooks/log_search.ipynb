# %%
import random

print(','.join([f'**{j}**' for j in range(10)]))
k = 115
for i in range(15):
    values = [f'**{i}**']
    for j in range(10):
        values.append(str(k))
        k += random.randint(1, 8)
    print(','.join(values))

# %%
import math

# %%
i = 64
j = 143
x = 400
ai = 400
aj = 796
k = round(i + (j - i) * (x - ai) / (aj - ai))
print(k)
